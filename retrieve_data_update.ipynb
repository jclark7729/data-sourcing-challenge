# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
# !pip install python-dotenv
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import os
from datetime import datetime

## Load the NASA_API_KEY from the env file
from dotenv import load_dotenv
load_dotenv()
NASA_API_KEY = os.getenv('NASA_API_KEY')

# %% [markdown]
# ### CME Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/CME?startDate=yyyy-MM-dd&endDate=yyyy-MM-dd"

# Set the specifier for CMEs:
CME = "CME"

# Search for CMEs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for CME
query_url = f"{base_url}{CME}?startDate={startDate}&endDate={endDate}&api_key={NASA_API_KEY}"

# %%
# Make a "GET" request for the CME URL and store it in a variable named cme_response
cme_response = requests.get(query_url)

# %%
# Convert cme_json to a Pandas DataFrame
cme_df = pd.DataFrame(cme_response.json())

# Keep only the columns: activityID, startTime, linkedEvents
cmd_df = cme_df[['activityID', 'startTime', 'linkedEvents']]

# %%
# Check if gst_json is empty before attemptin to access elements
if gst_json:
    # Preview the first result in JSON format
    # Use json.dumps with argument indent=4 to format data
    preview = json.dumps(gst_json[0], indent=4)
    print(preview)
else:
    print("gst_json is empty.")
# Out:
# {
#     "gstID": "2025-01-01T09:00:00-GST-001",
#     "startTime": "2025-01-01T09:00Z",
#     "allKpIndex": [
#         {
#             "observedTime": "2025-01-01T12:00Z",
#             "kpIndex": 6.33,
#             "source": "NOAA"
#         },
#         {
#             "observedTime": "2025-01-01T15:00Z",
#             "kpIndex": 6.67,
#             "source": "NOAA"
#         },
#         {
#             "observedTime": "2025-01-01T18:00Z",
#             "kpIndex": 8.0,
#             "source": "NOAA"
#         },
#         {
#             "observedTime": "2025-01-01T21:00Z",
#             "kpIndex": 6.67,
#             "source": "NOAA"
#         }
#     ],
#     "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/36159/-1",
#     "linkedEvents": [
#         {
#             "activityID": "2024-12-29T01:23:00-CME-001"
#         },
#         {
#             "activityID": "2024-12-29T06:24:00-CME-001"
#         },
#         {
# ...

# %%
# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
preview = json.dumps(cme_json[0], indent=4)
print(preview)
# Out:
# {
#     "activityID": "2024-12-13T00:00:00-CME-001",
#     "catalog": "M2M_CATALOG",
#     "startTime": "2024-12-13T00:00Z",
#     "instruments": [
#         {
#             "displayName": "SOHO: LASCO/C2"
#         },
#         {
#             "displayName": "SOHO: LASCO/C3"
#         },
#         {
#             "displayName": "STEREO A: SECCHI/COR2"
#         }
#     ],
#     "sourceLocation": "",
#     "activeRegionNum": null,
#     "note": "This CME is visible to the south/southeast in SOHO LASCO C2/C3 and STEREO A COR2 imagery. The source is likely far-sided as there are no source signatures visible on the Earth-facing disk at the time of this event.",
#     "submissionTime": "2024-12-13T03:24Z",
#     "versionId": 1,
#     "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/35626/-1",
#     "cmeAnalyses": [
#         {
#             "isMostAccurate": true,
#             "time21_5": "2024-12-13T08:27Z",
#             "latitude": -65.0,
#             "longitude": -27.0,
# ...

# %%
# Notice that the linkedEvents column allows us to identify the corresponding GST
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to GSTs
remove_missing_linkedEvents = [item for item in cme_json if 'linkedEvents' in item]

# Convert the filtered JSON response to a Pandas DataFrame
cme_df_filtered = pd.DataFrame(remove_missing_linkedEvents)

# Keep only the necessary columns: activityID, startTime, linkedEvents
cme_df_filtered = cme_df_filtered[['activityID', 'startTime', 'linkedEvents']]

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Write a nested for loop that iterates first over each row in the cme DataFrame (using the index)
# and then iterates over the values in 'linkedEvents'
# and adds the elements individually to a list of dictionaries where each row is one element
nested_loop = []

# Initialize an empty list to store the expanded rows
list_of_rows = []

# Iterate over each entry in the filtered JSON list
for entry in remove_missing_linkedEvents:
    # Check if 'linkedEvents' key exists and its value is a list
    if 'linkedEvents' in entry and isinstance(entry['linkedEvents'], list):
        # Iterate over each dictionary in the 'linkedEvents' list
        for linked_event in entry['linkedEvents']:
            # Append a new dictionary to the list_of_rows list for each linked_event and corresponding 'activityID' and 'startTime' value
            list_of_rows.append({
                'activityID': entry['activityID'],
                'startTime': entry['startTime'],
                'linkedEvents': linked_event
            })

# Create a new DataFrame from the expanded rows
df = pd.DataFrame(list_of_rows)

# Display the new DataFrame
display(df)
# Out:
#                      activityID          startTime  \
# 0   2024-12-13T02:48:00-CME-001  2024-12-13T02:48Z
# 1   2024-12-13T04:17:00-CME-001  2024-12-13T04:17Z
# 2   2024-12-14T05:36:00-CME-001  2024-12-14T05:36Z
# 3   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# 4   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# ..                          ...                ...
# 58  2025-01-06T23:00:00-CME-001  2025-01-06T23:00Z
# 59  2025-01-07T10:36:00-CME-001  2025-01-07T10:36Z
# 60  2025-01-07T23:12:00-CME-001  2025-01-07T23:12Z
# 61  2025-01-10T11:23:00-CME-001  2025-01-10T11:23Z
# 62  2025-01-11T09:09:00-CME-001  2025-01-11T09:09Z
#
#                                      linkedEvents
# 0   {'activityID': '2024-12-13T02:21:00-FLR-001'}
# 1   {'activityID': '2024-12-13T03:11:00-FLR-001'}
# 2   {'activityID': '2024-12-14T06:20:00-FLR-001'}
# 3   {'activityID': '2024-12-17T04:40:00-IPS-001'}
# 4   {'activityID': '2024-12-18T06:15:00-IPS-001'}
# ...

# %%
# Create a function called extract_activityID_from_dict that takes a dict as input such as in linkedEvents
def extract_activityID_from_dict(x):
    try:
      return x['activityID'] if 'activityID' in x else None
    except Exception as e:
      print(f"Error: {e}")
      return None

# and verify below that it works as expected using one row from linkedEvents as an example
verify = df.iloc[0]['linkedEvents']
print(extract_activityID_from_dict(verify))
# Be sure to use a try and except block to handle errors
df['GST_ActivityID'] = df['linkedEvents'].apply(lambda row: extract_activityID_from_dict(row))
display(df)
# Out:
# 2024-12-13T02:21:00-FLR-001
#                      activityID          startTime  \
# 0   2024-12-13T02:48:00-CME-001  2024-12-13T02:48Z
# 1   2024-12-13T04:17:00-CME-001  2024-12-13T04:17Z
# 2   2024-12-14T05:36:00-CME-001  2024-12-14T05:36Z
# 3   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# 4   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# ..                          ...                ...
# 58  2025-01-06T23:00:00-CME-001  2025-01-06T23:00Z
# 59  2025-01-07T10:36:00-CME-001  2025-01-07T10:36Z
# 60  2025-01-07T23:12:00-CME-001  2025-01-07T23:12Z
# 61  2025-01-10T11:23:00-CME-001  2025-01-10T11:23Z
# 62  2025-01-11T09:09:00-CME-001  2025-01-11T09:09Z
#
#                                      linkedEvents               GST_ActivityID
# 0   {'activityID': '2024-12-13T02:21:00-FLR-001'}  2024-12-13T02:21:00-FLR-001
# 1   {'activityID': '2024-12-13T03:11:00-FLR-001'}  2024-12-13T03:11:00-FLR-001
# 2   {'activityID': '2024-12-14T06:20:00-FLR-001'}  2024-12-14T06:20:00-FLR-001
# ...

# %%
# Apply this function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
df.loc[:, 'GST_ActivityID'] = df['linkedEvents'].apply(lambda row: extract_activityID_from_dict(row))

# and create a new column called 'GST_ActivityID' using loc indexer:
df.loc[:, 'GST_ActivityID'] = df['linkedEvents'].apply(lambda row: extact_activityID_from_dict(row))
display(df)
# Out:
#                      activityID          startTime  \
# 0   2024-12-13T02:48:00-CME-001  2024-12-13T02:48Z
# 1   2024-12-13T04:17:00-CME-001  2024-12-13T04:17Z
# 2   2024-12-14T05:36:00-CME-001  2024-12-14T05:36Z
# 3   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# 4   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# ..                          ...                ...
# 58  2025-01-06T23:00:00-CME-001  2025-01-06T23:00Z
# 59  2025-01-07T10:36:00-CME-001  2025-01-07T10:36Z
# 60  2025-01-07T23:12:00-CME-001  2025-01-07T23:12Z
# 61  2025-01-10T11:23:00-CME-001  2025-01-10T11:23Z
# 62  2025-01-11T09:09:00-CME-001  2025-01-11T09:09Z
#
#                                      linkedEvents               GST_ActivityID
# 0   {'activityID': '2024-12-13T02:21:00-FLR-001'}  2024-12-13T02:21:00-FLR-001
# 1   {'activityID': '2024-12-13T03:11:00-FLR-001'}  2024-12-13T03:11:00-FLR-001
# 2   {'activityID': '2024-12-14T06:20:00-FLR-001'}  2024-12-14T06:20:00-FLR-001
# ...

# %%
# Remove rows with missing GST_ActivityID, since we can't assign them to GSTs:
missing_GST_ActivityID = df.dropna(subset=['GST_ActivityID'])

# %%
# print out the datatype of each column in this DataFrame:
column_datatypes = missing_GST_ActivityID.dtypes
print(column_datatypes)
# Out:
# activityID        object
# startTime         object
# linkedEvents      object
# GST_ActivityID    object
# dtype: object

# %%
import pandas as pd

# Sample data for testing
data = {
    'GST_ActivityID': ['GST_1', 'Other_2', 'GST_3'],
    'activityID': [1, 2, 3],
    'startTime': ['2025-01-12 10:00', '2025-01-13 11:00', '2025-01-14 12:00'],
    'linkedEvents': ['Event1', 'Event2', 'Event3']
}

# Create a DataFrame
missing_GST_ActivityID = pd.DataFrame(data)

# Convert 'GST_ActivityID' column to string format
missing_GST_ActivityID['GST_ActivityID'] = missing_GST_ActivityID['GST_ActivityID'].astype(str)

# Convert 'activityID' column to string format
missing_GST_ActivityID['activityID'] = missing_GST_ActivityID['activityID'].astype(str)

# Convert 'startTime' to datetime format
missing_GST_ActivityID['startTime'] = pd.to_datetime(missing_GST_ActivityID['startTime'])

# Rename 'startTime' to 'startTime_CME' and 'activityID' to 'cmeID'
renamed_df = missing_GST_ActivityID.rename(columns={'startTime': 'startTime_CME', 'activityID': 'cmeID'})

# Convert 'cmeID' column to string format
renamed_df['cmeID'] = renamed_df['cmeID'].astype(str)

# Drop 'linkedEvents' column
renamed_df = renamed_df.drop(columns=['linkedEvents'])

# Verify that all steps were executed correctly
display(renamed_df)

# Print out the datatype of each column in this DataFrame
column_datatypes = renamed_df.dtypes
print(column_datatypes)
# Out:
#   GST_ActivityID cmeID       startTime_CME
# 0          GST_1     1 2025-01-12 10:00:00
# 1        Other_2     2 2025-01-13 11:00:00
# 2          GST_3     3 2025-01-14 12:00:00
# GST_ActivityID            object
# cmeID                     object
# startTime_CME     datetime64[ns]
# dtype: object

# %%
# We are only interested in CMEs related to GSTs so keep only rows where the GST_ActivityID column contains 'GST'
# use the method 'contains()' from the str library.
renamed_df = renamed_df[renamed_df['GST_ActivityID'].str.contains('GST')]
display(renamed_df)
# Out:
#                           cmeID      startTime_CME  \
# 23  2024-12-29T01:23:00-CME-001  2024-12-29T01:23Z
# 28  2024-12-29T06:24:00-CME-001  2024-12-29T06:24Z
#
#                  GST_ActivityID
# 23  2025-01-01T09:00:00-GST-001
# 28  2025-01-01T09:00:00-GST-001

# %% [markdown]
# ### GST Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/GST?startDate=yyyy-MM-dd&endDate=yyyy-MM-dd"

# Set the specifier for Geomagnetic Storms (GST):
GST = "GST"

# Search for GSTs between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for GST
query_url = f"{base_url}{GST}?startDate={startDate}&endDate={endDate}&api_key={NASA_API_KEY}"

# %%
# Make a "GET" request for the GST URL and store it in a variable named gst_response
gst_response = requests.get(query_url)

# %%
# Convert the response variable to json and store it as a variable named gst_json
gst_response = requests.get(query_url)
gst_json = gst_response.json()

# Check if gst_json is empty before attempting to access elements
if gst_json:

    # Preview the first result in JSON format
    # Use json.dumps with argument indent=4 to format data
    preview = json.dumps(gst_json[0], indent=4)
    print(preview)
else:
    print("gst_json is empty.")
# Out:
# {
#     "gstID": "2025-01-01T09:00:00-GST-001",
#     "startTime": "2025-01-01T09:00Z",
#     "allKpIndex": [
#         {
#             "observedTime": "2025-01-01T12:00Z",
#             "kpIndex": 6.33,
#             "source": "NOAA"
#         },
#         {
#             "observedTime": "2025-01-01T15:00Z",
#             "kpIndex": 6.67,
#             "source": "NOAA"
#         },
#         {
#             "observedTime": "2025-01-01T18:00Z",
#             "kpIndex": 8.0,
#             "source": "NOAA"
#         },
#         {
#             "observedTime": "2025-01-01T21:00Z",
#             "kpIndex": 6.67,
#             "source": "NOAA"
#         }
#     ],
#     "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/36159/-1",
#     "linkedEvents": [
#         {
#             "activityID": "2024-12-29T01:23:00-CME-001"
#         },
#         {
#             "activityID": "2024-12-29T06:24:00-CME-001"
#         },
#         {
# ...

# %%
# Convert gst_json to a Pandas DataFrame
gst_df = pd.DataFrame(gst_response.json())

# Check if the DataFrame is empty before selecting columns
if not gst_df.empty:
    # Keep only the columns: activityID, startTime, linkedEvents
    selected_columns = ['gstID', 'startTime', 'linkedEvents']
    gst_df = gst_df[selected_columns]
    display(gst_df)
else:
    print("gst_df is empty.")
# Out:
#                          gstID          startTime  \
# 0  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
#
#                                         linkedEvents
# 0  [{'activityID': '2024-12-29T01:23:00-CME-001'}...

# %%
# Notice that the linkedEvents column allows us to identify the corresponding CME
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to CME
Remove_missing_linkedEvents = [item for item in gst_json if 'linkedEvents' in item]

# Convert the filtered JSON response to a Pandas DataFrame
filtered_gst_df = pd.DataFrame(Remove_missing_linkedEvents)

# Keep only the necessary columns: gstID, startTime, linkedEvents
selected_columns = ['gstID', 'startTime', 'linkedEvents']
filtered_gst_df = filtered_gst_df[selected_columns]

# Display the filtered DataFrame
display(filtered_gst_df)
# Out:
#                          gstID          startTime  \
# 0  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
#
#                                         linkedEvents
# 0  [{'activityID': '2024-12-29T01:23:00-CME-001'}...

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Use the explode method to ensure that each row is one element. Ensure to reset the index and drop missing values.
exploded_df = pd.DataFrame(Remove_missing_linkedEvents)

# Check if 'linkedEvents' column exists before exploding
if 'linkedEvents' in exploded_df.columns:
    exploded_df = exploded_df.explode('linkedEvents')
    exploded_df = exploded_df.dropna(subset=['linkedEvents'])
    exploded_df = exploded_df.reset_index(drop=True)
else:
    print("'linkedEvents' column not found in the DataFrame.")

display(exploded_df)
# Out:
#                          gstID          startTime  \
# 0  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
# 1  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
# 2  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
# 3  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
#
#                                           allKpIndex  \
# 0  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
# 1  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
# 2  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
# 3  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
#
#                                                 link  \
# 0  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
# 1  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
# 2  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
# 3  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
#
#                                     linkedEvents     submissionTime  versionId
# 0  {'activityID': '2024-12-29T01:23:00-CME-001'}  2025-01-01T12:35Z          1
# ...

# %%
# Apply the extract_activityID_from_dict function to each row in the 'linkedEvents' column
exploded_df.loc[:, 'CME_ActivityID'] = exploded_df['linkedEvents'].apply(lambda row: extract_activityID_from_dict(row))

# Remove rows with missing CME_ActivityID, since we can't assign them to CMEs:
missing_CME_ActivityID = exploded_df.dropna(subset=['CME_ActivityID'])

# Display the updated DataFrame
display(exploded_df)
# Out:
#                          gstID          startTime  \
# 0  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
# 1  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
# 2  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
# 3  2025-01-01T09:00:00-GST-001  2025-01-01T09:00Z
#
#                                           allKpIndex  \
# 0  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
# 1  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
# 2  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
# 3  [{'observedTime': '2025-01-01T12:00Z', 'kpInde...
#
#                                                 link  \
# 0  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
# 1  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
# 2  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
# 3  https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GS...
#
#                                     linkedEvents     submissionTime  \
# 0  {'activityID': '2024-12-29T01:23:00-CME-001'}  2025-01-01T12:35Z
# ...

# %%
import pandas as pd

# Convert 'CME_ActivityID' column to string format
missing_CME_ActivityID['CME_ActivityID'] = missing_CME_ActivityID['CME_ActivityID'].astype(str)

# Convert 'gstID' column to string format (corrected column name from 'activityID' to 'gstID')
missing_CME_ActivityID['gstID'] = missing_CME_ActivityID['gstID'].astype(str)

# Convert startTime to datetime format
missing_CME_ActivityID['startTime'] = pd.to_datetime(missing_CME_ActivityID['startTime'])

# Rename 'startTime' to 'startTime_GST' and 'activityID' to 'gstID' (done in one step)
renamed_df = missing_CME_ActivityID.rename(columns={'startTime': 'startTime_GST', 'activityID': 'gstID'})

# Create a copy of renamed_df and rename 'startTime_GST' to 'startTime_CME' and 'gstID' to 'cmeID'
renamed_df2 = renamed_df.rename(columns={'startTime_GST': 'startTime_CME', 'gstID': 'cmeID'})

# Drop 'linkedEvents' column
dropped_df = missing_CME_ActivityID.drop(columns=['linkedEvents'])

# Verify that all steps were executed correctly
print(dropped_df.dtypes)
# Out:
# gstID                          object
# startTime         datetime64[ns, UTC]
# allKpIndex                     object
# link                           object
# submissionTime                 object
# versionId                       int64
# CME_ActivityID                 object
# dtype: object

# %%
# We are only interested in GSTs related to CMEs so keep only rows where the CME_ActivityID column contains 'CME'
# use the method 'contains()' from the str library.
CME_ActivityID_df = dropped_df[dropped_df['CME_ActivityID'].str.contains('CME')]

# %% [markdown]
# ### Merge both datatsets

# %%
# Now merge both datasets using 'gstID' and 'CME_ActivityID' for gst and 'GST_ActivityID' and 'cmeID' for cme. Use the 'left_on' and 'right_on' specifiers.

df.merge(CME_ActivityID, left_on='GST_ActivityID', right_on='CME_ActivityID', how='left')
# Out:
#                      activityID          startTime  \
# 0   2024-12-13T02:48:00-CME-001  2024-12-13T02:48Z
# 1   2024-12-13T04:17:00-CME-001  2024-12-13T04:17Z
# 2   2024-12-14T05:36:00-CME-001  2024-12-14T05:36Z
# 3   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# 4   2024-12-15T01:25:00-CME-001  2024-12-15T01:25Z
# ..                          ...                ...
# 92  2025-01-06T23:00:00-CME-001  2025-01-06T23:00Z
# 93  2025-01-07T10:36:00-CME-001  2025-01-07T10:36Z
# 94  2025-01-07T23:12:00-CME-001  2025-01-07T23:12Z
# 95  2025-01-10T11:23:00-CME-001  2025-01-10T11:23Z
# 96  2025-01-11T09:09:00-CME-001  2025-01-11T09:09Z
#
#                                      linkedEvents  \
# 0   {'activityID': '2024-12-13T02:21:00-FLR-001'}
# 1   {'activityID': '2024-12-13T03:11:00-FLR-001'}
# 2   {'activityID': '2024-12-14T06:20:00-FLR-001'}
# 3   {'activityID': '2024-12-17T04:40:00-IPS-001'}
# 4   {'activityID': '2024-12-17T04:40:00-IPS-001'}
# ...

# %%
# Verify that the new DataFrame has the same number of rows as cme and gst
row_count_cme = len(cmeID)
row_count_gst = len(gstID)
row_count_merge = len(df.merge(CME_ActivityID, left_on='GST_ActivityID', right_on='CME_ActivityID', how='left'))

# Print the row counts
print("Number of rows in CME DataFrame:", row_count_cme)
print("Number of rows in GST DataFrame:", row_count_gst)
print("Number of rows in merged DataFrame:", row_count_merge)
# Out:
# Number of rows in CME DataFrame: 63
# Number of rows in GST DataFrame: 63
# Number of rows in merged DataFrame: 97

# %% [markdown]
# ### Computing the time it takes for a CME to cause a GST

# %%
# Compute the time diff between startTime_GST and startTime_CME by creating a
# new column called `timeDiff`. Define 'startTime'
def timeDiff(df):
  df['timeDiff'] = df['startTime_GST'] - df['startTime_CME']
  return df

# %%
# Use describe() to compute the mean and median time
# that it takes for a CME to cause a GST.

def mean_median_timeDiff(df):
  mean_timeDiff = df['timeDiff'].mean()
  median_timeDiff = df['timeDiff'].median()
  return mean_timeDiff, median_timeDiff
df.describe()
# Out:
#                          activityID          startTime  \
# count                            63                 63
# unique                           36                 36
# top     2025-01-04T15:12:00-CME-001  2025-01-04T15:12Z
# freq                              8                  8
#
#                                          linkedEvents  \
# count                                              63
# unique                                             47
# top     {'activityID': '2025-01-01T01:20:00-IPS-001'}
# freq                                                3
#
#                      GST_ActivityID
# count                            63
# unique                           47
# top     2025-01-01T01:20:00-IPS-001
# freq                              3

# %% [markdown]
# ### Exporting data in csv format

# %%
# Export data to CSV without the index
df.to_csv('CME_GST_Data.csv', index=False)
